# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathieluri31/FMML_LAB_MODULES/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
# Initialize starting point
new_x = 3  # Initial guess
learning_rate = 0.1  # Learning rate

# Gradient descent
for n in range(500):
    previous_x = new_x

    # Calculate gradient at the current point
    gradient = 2 * (previous_x - 5)  # Derivative of f(x) = (x - 5)^2

    # Update x using gradient descent formula: x = x - learning_rate * gradient
    new_x = previous_x - learning_rate * gradient

    # Stopping criterion - check for convergence
    if abs(new_x - previous_x) < 1e-6:
        print(f'Converged at iteration {n} with x = {new_x}')
        break
# Out:
# Converged at iteration 58 with x = 4.9999961687611485

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and its derivative
def f(x):
    return x**2 + x + 1

def df(x):
    return 2*x + 1

# Gradient Descent
def gradient_descent(starting_point, learning_rate, iterations):
    x_list = [starting_point]
    slope_list = [df(starting_point)]
    for i in range(iterations):
        new_x = x_list[-1] - learning_rate * df(x_list[-1])
        x_list.append(new_x)
        slope_list.append(df(new_x))
    return x_list, slope_list

# Parameters for gradient descent
starting_point = -2
learning_rate = 0.3
iterations = 20

# Run gradient descent
x_list, slope_list = gradient_descent(starting_point, learning_rate, iterations)

# Create x values for the plots
x_1 = np.linspace(-3, 3, 1000)

# Superimpose the gradient descent calculations on the plot
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)
values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)
plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

plt.show()

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to optimize (f(x) = (x - 5)^2)
def func(x):
    return (x - 5) ** 2

# Derivative of the function (f'(x) = 2(x - 5))
def derivative(x):
    return 2 * (x - 5)

# Plotting the function and its derivative
x_vals = np.linspace(0, 10, 100)
y_func = func(x_vals)
y_deriv = derivative(x_vals)

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot function
axs[0].plot(x_vals, y_func, label='f(x) = (x - 5)^2')
axs[0].set_title('Function f(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('f(x)')
axs[0].legend()

# Plot derivative
axs[1].plot(x_vals, y_deriv, label="f'(x) = 2(x - 5)")
axs[1].set_title("Derivative f'(x)")
axs[1].set_xlabel('x')
axs[1].set_ylabel("f'(x)")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Call the gradient descent function
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001, 1000)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.0234052067759206
# Number of steps: 76

# %%
# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=1000):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Call the gradient descent function with keyword arguments
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004894871981406463
# Number of steps: 230

# %%
# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = 2x

# Gradient descent function with default parameters
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Call the gradient descent function with specified arguments
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004829602124348781
# Number of steps: 151

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the derivative function
def dg(x):
    return 2 * x  # Example derivative of g(x) = x^2

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0)

# Define the cost function g(x) and its range of x values (example)
def g(x):
    return x**2  # Example cost function g(x) = x^2

x_vals = np.linspace(-2, 2, 100)  # Example range of x values
cost_vals = g(x_vals)  # Compute corresponding g(x) values

# Plotting
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_vals, cost_vals, color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_vals, dg(x_vals), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.0234052067759206
# Number of steps: 76

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004894871981406463
# Number of steps: 230

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004829602124348781
# Number of steps: 151

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = x^2 is f'(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=3)

# Define the cost function f(x) and its range of x values
def f(x):
    return x**2  # Cost function f(x) = x^2

x_vals = np.linspace(-4, 4, 100)  # Range of x values
cost_vals = f(x_vals)  # Compute corresponding f(x) values

# Plotting
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Cost function: f(x) = x^2', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_vals, cost_vals, color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, f(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Derivative of the cost function: f\'(x) = 2x', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f\'(x)', fontsize=16)
plt.grid()
plt.plot(x_vals, dg(x_vals), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  165

# %%
## TASK-5 : Run gradient descent 3 times
import numpy as np
import matplotlib.pyplot as plt

# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = x^2 is f'(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    list_x = [new_x]
    deriv_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))

        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break

    return new_x, list_x, deriv_list

# Run gradient descent three times with different initial guesses
local_min_1, list_x_1, deriv_list_1 = gradient_descent(derivative_func=dg, initial_guess=3)
local_min_2, list_x_2, deriv_list_2 = gradient_descent(derivative_func=dg, initial_guess=-2)
local_min_3, list_x_3, deriv_list_3 = gradient_descent(derivative_func=dg, initial_guess=1.5)

# Define the cost function f(x) and its range of x values
def f(x):
    return x**2  # Cost function f(x) = x^2

x_vals = np.linspace(-4, 4, 100)  # Range of x values
cost_vals = f(x_vals)  # Compute corresponding f(x) values

# Plotting for the first run
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Cost function: f(x) = x^2', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_vals, cost_vals, color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_1, f(np.array(list_x_1)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Derivative of the cost function: f\'(x) = 2x', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f\'(x)', fontsize=16)
plt.grid()
plt.plot(x_vals, dg(x_vals), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_1, deriv_list_1, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# Plotting for the second run
plt.figure(figsize=[15, 5])
# Include code similar to the first plotting for list_x_2 and deriv_list_2 here

# Plotting for the third run
plt.figure(figsize=[15, 5])


## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100

# Low gamma experiment
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

# Mid gamma experiment
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.01, precision=0.0001, max_iter=n)

# High gamma experiment
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.1, precision=0.0001, max_iter=n)

# Experiment with a high gamma value
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the results
plt.figure(figsize=[15, 10])

# Plotting for low gamma
plt.subplot(2, 2, 1)
plt.title('Low Gamma: multiplier=0.0005', fontsize=15)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('X Value', fontsize=12)
plt.plot(low_gamma[1], label='low_gamma', color='blue')
plt.legend()

# Plotting for mid gamma
plt.subplot(2, 2, 2)
plt.title('Mid Gamma: multiplier=0.01', fontsize=15)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('X Value', fontsize=12)
plt.plot(mid_gamma[1], label='mid_gamma', color='green')
plt.legend()

# Plotting for high gamma
plt.subplot(2, 2, 3)
plt.title('High Gamma: multiplier=0.1', fontsize=15)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('X Value', fontsize=12)
plt.plot(high_gamma[1], label='high_gamma', color='red')
plt.legend()

# Plotting for insane gamma
plt.subplot(2, 2, 4)
plt.title('Insane Gamma: multiplier=0.25', fontsize=15)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('X Value', fontsize=12)
plt.plot(insane_gamma[1], label='insane_gamma', color='orange')
plt.legend()

plt.tight_layout()
plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = x^2 is f'(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.0001, max_iter=1000):
    current_x = initial_guess
    list_x = [current_x]
    deriv_list = [derivative_func(current_x)]

    for _ in range(max_iter):
        previous_x = current_x
        gradient = derivative_func(previous_x)
        current_x = previous_x - multiplier * gradient

        list_x.append(current_x)
        deriv_list.append(derivative_func(current_x))

        if abs(current_x - previous_x) < precision:
            break

    return current_x, list_x, deriv_list

# Function to calculate cost values for an experiment
def calculate_cost_values(experiment):
    cost_vals = np.array([x**2 for x in experiment])
    return cost_vals[0] - cost_vals

# Run gradient descent
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
cost_reduction_low_gamma = calculate_cost_values(low_gamma[1])

# Plotting the reduction in cost for each iteration
plt.figure(figsize=[10, 6])
iterations = np.arange(1, n+2)  # Incrementing to match the length of gradient descent output

plt.plot(iterations, cost_reduction_low_gamma, label='Low Gamma: multiplier=0.0005', color='blue')

plt.title('Reduction in Cost for Each Iteration', fontsize=15)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the derivative function
def dg(x):
    return 2 * x  # Derivative of f(x) = x^2 is f'(x) = 2x

# Gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.0001, max_iter=1000):
    current_x = initial_guess
    list_x = [current_x]
    deriv_list = [derivative_func(current_x)]

    for _ in range(max_iter):
        previous_x = current_x
        gradient = derivative_func(previous_x)
        current_x = previous_x - multiplier * gradient

        list_x.append(current_x)
        deriv_list.append(derivative_func(current_x))

        if abs(current_x - previous_x) < precision:
            break

    return current_x, list_x, deriv_list

# Function to calculate cost values for an experiment
def calculate_cost_values(experiment):
    cost_vals = np.array([x**2 for x in experiment])
    return cost_vals[0] - cost_vals

# Run gradient descent for low gamma
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
cost_reduction_low_gamma = calculate_cost_values(low_gamma[1])

# Plotting the reduction in cost for each iteration for low gamma
plt.figure(figsize=[10, 6])
iterations = np.arange(1, n+2)  # Incrementing to match the length of gradient descent output

plt.plot(iterations, cost_reduction_low_gamma, label='Low Gamma: multiplier=0.0005', color='blue')

plt.title('Reduction in Cost for Each Iteration (Low Gamma)', fontsize=15)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function to be optimized
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generating x, y values
x_4 = np.linspace(-6, 6, 30)
y_4 = np.linspace(-6, 6, 30)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)  # Using the function f(x, y)

# Plotting in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.set_title('Surface Plot of f(x, y)', fontsize=20)
ax.set_xlabel('X-axis', fontsize=16)
ax.set_ylabel('Y-axis', fontsize=16)
ax.set_zlabel('f(x, y) - Cost', fontsize=16)

ax.plot_surface(x_4, y_4, z_4, cmap='coolwarm', alpha=0.4)

plt.show()

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function to be optimized
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generating x, y values
x_4 = np.linspace(-6, 6, 30)
y_4 = np.linspace(-6, 6, 30)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)  # Using the function f(x, y)

# Plotting in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.set_title('Surface Plot of f(x, y)', fontsize=20)
ax.set_xlabel('X-axis', fontsize=16)
ax.set_ylabel('Y-axis', fontsize=16)
ax.set_zlabel('f(x, y) - Cost', fontsize=16)

# Complete the next line to plot the surface
ax.plot_surface(x_4, y_4, z_4, cmap='coolwarm', alpha=0.4)

plt.show()

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
import numpy as np
from sympy import symbols, sin, sqrt, diff

# Define symbols for the variables
x, y = symbols('x y')

# Define the function to be optimized
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Given parameters
params = [2, 3]  # Example parameters

# Compute gradients using symbolic differentiation
gradient_x = diff(f(x, y), x).evalf(subs={x: params[0], y: params[1]})
gradient_y = diff(f(x, y), y).evalf(subs={x: params[0], y: params[1]})

# Print the gradients
print(f"Gradient with respect to x: {gradient_x}")
print(f"Gradient with respect to y: {gradient_y}")
# Out:
# Gradient with respect to x: -0.496061761564155
# Gradient with respect to y: -0.744092642346232

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [-3.81217567902896e-15 -2.11787537723831e-15]
# Minimum occurs at x value of:  4.11936911511823
# Minimum occurs at y value of:  2.28853839728790
# The cost is:  -1.00000000000000

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
import numpy as np
from sympy import symbols, sin, sqrt, diff

# Define symbols for x and y
x, y = symbols('x y')

# Define the function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Calculate partial derivatives with respect to x and y
def fpx(x_val, y_val):
    return diff(f(x, y), x).evalf(subs={x: x_val, y: y_val})

def fpy(x_val, y_val):
    return diff(f(x, y), y).evalf(subs={x: x_val, y: y_val})

# Given multipliers and initial parameters
multiplier = 0.1
params = np.array([2, 3])  # Example initial parameters

max_iter = 100  # Set the maximum number of iterations for optimization

# Optimization loop
for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])

    # Check if gradients are valid before updating
    if gradient_x is not None and gradient_y is not None:
        gradients = np.array([gradient_x, gradient_y])
        params = params - multiplier * gradients
    else:
        # Handle the case where gradients are None (not computed properly)
        print("Gradients are None. Check the gradient calculation functions.")
        break

# Results or further processing
print("Optimized parameters:", params)
# Out:
# Optimized parameters: [2.61394455464388 3.92091683196582]

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-6.41083846776318e-9 -3.56157692653510e-9]
# Minimum occurs at x value of:  4.11936910934848
# Minimum occurs at y value of:  2.28853839408249
# The cost is:  -1.00000000000000

# %%
import numpy as np
from sympy import symbols, sin, sqrt, diff

# Define symbols for x and y
x, y = symbols('x y')

# Define the function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Calculate partial derivatives with respect to x and y
def fpx(x_val, y_val):
    return diff(f(x, y), x).evalf(subs={x: x_val, y: y_val})

def fpy(x_val, y_val):
    return diff(f(x, y), y).evalf(subs={x: x_val, y: y_val})

# Given multipliers and initial parameters
multiplier = 0.1
params = np.array([2, 3], dtype=float)  # Example initial parameters

max_iter = 100  # Set the maximum number of iterations for optimization

# Optimization loop
for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])

    # Check if gradients are valid before updating
    if gradient_x is not None and gradient_y is not None:
        gradients = np.array([gradient_x, gradient_y], dtype=float)
        params = params - multiplier * gradients
    else:
        # Handle the case where gradients are None (not computed properly)
        print("Gradients are None. Check the gradient calculation functions.")
        break

# Results or further processing
print("Optimized parameters:", params)
# Out:
# Optimized parameters: [2.61394455 3.92091683]

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
